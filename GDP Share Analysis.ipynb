# %%
import pandas as pd
import numpy as np
gdp_sh_df= pd.read_csv('GDP Share.csv',index_col=0)

# %%
gdp_sh_df
# Out:
#                 Gross Domestic Product (in Rs. Cr) at 2004-05 Prices  \
# Financial Year
# 1951-52                                                    286147
# 1952-53                                                    294267
# 1953-54                                                    312177
# 1954-55                                                    325431
# 1955-56                                                    333766
# ...                                                           ...
# 2007-08                                                   3896636
# 2008-09                                                   4158676
# 2009-10                                                   4516071
# 2010-11                                                   4937006
# 2011-12                                                   5243582
#
#                 Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# Financial Year
# ...

# %%
gdp_sh_df=gdp_sh_df.iloc[:,7:13]

# %%
gdp_sh_df
# Out:
#                 Agri-culture & Allied Services -Share to Total GDP  \
# Financial Year
# 1951-52                                                      5145
# 1952-53                                                      5161
# 1953-54                                                      5239
# 1954-55                                                      5173
# 1955-56                                                      5001
# ...                                                           ...
# 2007-08                                                      1681
# 2008-09                                                      1577
# 2009-10                                                      1464
# 2010-11                                                      1445
# 2011-12                                                      1410
#
#                 Agriculture - Share to Total GDP  \
# Financial Year
# 1951-52                                     4154
# ...

# %%
gdp_sh_df=gdp_sh_df.div(100)

# %%
gdp_sh_df.to_csv('GDP Share in Percent.csv')

# %%
gdp_sh_df
# Out:
#                 Agri-culture & Allied Services -Share to Total GDP  \
# Financial Year
# 1951-52                                                     51.45
# 1952-53                                                     51.61
# 1953-54                                                     52.39
# 1954-55                                                     51.73
# 1955-56                                                     50.01
# ...                                                           ...
# 2007-08                                                     16.81
# 2008-09                                                     15.77
# 2009-10                                                     14.64
# 2010-11                                                     14.45
# 2011-12                                                     14.10
#
#                 Agriculture - Share to Total GDP  \
# Financial Year
# 1951-52                                    41.54
# ...

# %%
gdp_sh_df.rename(columns={"Agri-culture & Allied Services -Share to Total GDP":"Agri-culture & Allied Services",
                          "Agriculture - Share to Total GDP":"Agriculture",
                          "Industry - Share to Total GDP":"Industry",
                          "Mining and Quarrying - Share to Total GDP":"Mining and Quarrying",
                          "Manufacturing - Share to Total GDP":"Manufacturing",
                          "Services - Share to Total GDP":"Services"},inplace=True)

# %%
gdp_sh_df
# Out:
#                 Agri-culture & Allied Services  Agriculture  Industry  \
# Financial Year
# 1951-52                                  51.45        41.54     16.69
# 1952-53                                  51.61        42.08     16.22
# 1953-54                                  52.39        43.23     16.15
# 1954-55                                  51.73        42.63     16.77
# 1955-56                                  50.01        40.95     18.07
# ...                                        ...          ...       ...
# 2007-08                                  16.81        14.29     28.74
# 2008-09                                  15.77        13.36     28.13
# 2009-10                                  14.64        12.35     28.27
# 2010-11                                  14.45        12.29     28.23
# 2011-12                                  14.10        12.02     27.51
#
#                 Mining and Quarrying  Manufacturing  Services
# Financial Year
# ...
